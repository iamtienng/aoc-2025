# %%
pip install pulp
# Out:
# Collecting pulp
#   Using cached pulp-3.3.0-py3-none-any.whl.metadata (8.4 kB)
# Using cached pulp-3.3.0-py3-none-any.whl (16.4 MB)
# Installing collected packages: pulp
# Successfully installed pulp-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from typing import List, Tuple
import pulp


def parse_line(line: str) -> Tuple[List[List[int]], List[int]]:
    """
    Parse a line like:
    [.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
    Returns (buttons, targets)
    - buttons: list of lists of indices (each button's affected counters)
    - targets: list of integers (desired counter values)
    """
    s = line.strip()
    if not s:
        return [], []

    # Find braces part for targets
    lb = s.find("{")
    rb = s.find("}")
    if lb == -1 or rb == -1:
        raise ValueError("Line missing { } targets: " + line)
    targets_str = s[lb + 1 : rb]
    targets = [int(x.strip()) for x in targets_str.split(",") if x.strip() != ""]

    # buttons are the parenthesis groups before the '{'
    before = s[:lb]
    buttons: List[List[int]] = []
    pos = 0
    while True:
        i = before.find("(", pos)
        if i == -1:
            break
        j = before.find(")", i)
        if j == -1:
            break
        inside = before[i + 1 : j].strip()
        if inside == "":
            buttons.append([])
        else:
            idxs = [int(x.strip()) for x in inside.split(",") if x.strip() != ""]
            buttons.append(idxs)
        pos = j + 1

    # We only need the portion of each button that references valid counters (0..len(targets)-1)
    n = len(targets)
    buttons = [[x for x in btn if 0 <= x < n] for btn in buttons]

    return buttons, targets


def solve_machine_ilp(buttons: List[List[int]], targets: List[int]) -> int:
    """
    Formulate and solve:
      minimize sum_j x_j
      subject to: for each counter i: sum_j A[i][j] * x_j == targets[i]
                  x_j >= 0 and integer
    Returns minimal sum(x_j) as int.
    """
    m = len(buttons)
    n = len(targets)

    # Quick infeasibility check: any target>0 with no touching button -> impossible
    for i in range(n):
        if targets[i] > 0:
            touched = False
            for btn in buttons:
                if i in btn:
                    touched = True
                    break
            if not touched:
                raise RuntimeError(
                    f"Counter {i} has target {targets[i]} but no button touches it."
                )

    # Create ILP
    prob = pulp.LpProblem("machine", pulp.LpMinimize)

    # Variables: x_0 .. x_{m-1}, integer >= 0
    x_vars = [pulp.LpVariable(f"x_{j}", lowBound=0, cat="Integer") for j in range(m)]

    # Objective: minimize total presses
    prob += pulp.lpSum(x_vars)

    # Constraints: for each counter i
    for i in range(n):
        # sum over buttons that affect counter i of x_j == targets[i]
        coeffs = []
        vars_for_row = []
        for j in range(m):
            if i in buttons[j]:
                coeffs.append(1)
                vars_for_row.append(x_vars[j])
        # If there are no vars, we already checked infeasibility above
        prob += (pulp.lpSum(vars_for_row) == targets[i], f"counter_{i}")

    # Solve with CBC quietly
    prob.solve(pulp.PULP_CBC_CMD(msg=False))

    status = pulp.LpStatus[prob.status]
    if status != "Optimal":
        raise RuntimeError(f"ILP did not find optimal solution (status={status}).")

    # Retrieve solution and compute sum
    total = 0
    for j in range(m):
        val = x_vars[j].value()
        if val is None:
            raise RuntimeError("Variable has no value in solution.")
        # val may be float-like; cast to int
        iv = int(round(val))
        if iv < 0:
            raise RuntimeError("Negative press in solution.")
        total += iv

    return total


def solve_file(path: str) -> int:
    total_sum = 0
    p = Path(path)
    if not p.exists():
        raise FileNotFoundError(f"{path} not found.")
    with p.open() as fh:
        lineno = 0
        for line in fh:
            lineno += 1
            line = line.strip()
            if not line:
                continue
            buttons, targets = parse_line(line)
            try:
                machine_min = solve_machine_ilp(buttons, targets)
            except Exception as e:
                # Provide helpful error context
                raise RuntimeError(f"Error solving line {lineno}: {e}") from e
            print(f"Line {lineno}: min presses = {machine_min}")
            total_sum += machine_min
    return total_sum


if __name__ == "__main__":
    total = solve_file("../input.txt")
    with open("../output_part_two.txt", 'w') as out_file:
        out_file.write(f"{total}")
    print("Total min presses (Part Two) =", total)
# Out:
# Line 1: min presses = 138
# Line 2: min presses = 38
# Line 3: min presses = 52
# Line 4: min presses = 64
# Line 5: min presses = 62
# Line 6: min presses = 107
# Line 7: min presses = 199
# Line 8: min presses = 129
# Line 9: min presses = 78
# Line 10: min presses = 39
# Line 11: min presses = 237
# Line 12: min presses = 81
# Line 13: min presses = 107
# Line 14: min presses = 83
# Line 15: min presses = 111
# Line 16: min presses = 219
# Line 17: min presses = 81
# Line 18: min presses = 74
# Line 19: min presses = 93
# Line 20: min presses = 60
# Line 21: min presses = 93
# Line 22: min presses = 91
# Line 23: min presses = 180
# Line 24: min presses = 201
# Line 25: min presses = 222
# Line 26: min presses = 95
# Line 27: min presses = 66
# Line 28: min presses = 213
# Line 29: min presses = 8
# Line 30: min presses = 191
# Line 31: min presses = 39
# Line 32: min presses = 215
# Line 33: min presses = 26
# Line 34: min presses = 82
# Line 35: min presses = 68
# Line 36: min presses = 60
# Line 37: min presses = 53
# Line 38: min presses = 239
# Line 39: min presses = 56
# Line 40: min presses = 57
# Line 41: min presses = 57
# Line 42: min presses = 193
# Line 43: min presses = 37
# Line 44: min presses = 228
# Line 45: min presses = 76
# Line 46: min presses = 48
# Line 47: min presses = 26
# Line 48: min presses = 63
# Line 49: min presses = 93
# Line 50: min presses = 14
# Line 51: min presses = 42
# Line 52: min presses = 226
# Line 53: min presses = 156
# Line 54: min presses = 67
# Line 55: min presses = 57
# Line 56: min presses = 212
# Line 57: min presses = 206
# Line 58: min presses = 141
# Line 59: min presses = 89
# Line 60: min presses = 269
# Line 61: min presses = 171
# Line 62: min presses = 87
# Line 63: min presses = 77
# Line 64: min presses = 220
# Line 65: min presses = 87
# Line 66: min presses = 45
# Line 67: min presses = 72
# Line 68: min presses = 53
# Line 69: min presses = 58
# Line 70: min presses = 33
# Line 71: min presses = 191
# Line 72: min presses = 74
# Line 73: min presses = 50
# Line 74: min presses = 259
# Line 75: min presses = 74
# Line 76: min presses = 90
# Line 77: min presses = 80
# Line 78: min presses = 55
# Line 79: min presses = 115
# Line 80: min presses = 115
# Line 81: min presses = 275
# Line 82: min presses = 212
# Line 83: min presses = 60
# Line 84: min presses = 149
# Line 85: min presses = 50
# Line 86: min presses = 44
# Line 87: min presses = 73
# Line 88: min presses = 63
# Line 89: min presses = 72
# Line 90: min presses = 128
# Line 91: min presses = 91
# Line 92: min presses = 19
# Line 93: min presses = 147
# Line 94: min presses = 80
# Line 95: min presses = 73
# Line 96: min presses = 263
# Line 97: min presses = 59
# Line 98: min presses = 84
# Line 99: min presses = 142
# Line 100: min presses = 287
# Line 101: min presses = 90
# Line 102: min presses = 55
# Line 103: min presses = 118
# Line 104: min presses = 67
# Line 105: min presses = 74
# Line 106: min presses = 264
# Line 107: min presses = 85
# Line 108: min presses = 11
# Line 109: min presses = 150
# Line 110: min presses = 68
# Line 111: min presses = 144
# Line 112: min presses = 92
# Line 113: min presses = 199
# Line 114: min presses = 32
# Line 115: min presses = 39
# Line 116: min presses = 46
# Line 117: min presses = 11
# Line 118: min presses = 109
# Line 119: min presses = 185
# Line 120: min presses = 56
# Line 121: min presses = 23
# Line 122: min presses = 178
# Line 123: min presses = 317
# Line 124: min presses = 82
# Line 125: min presses = 113
# Line 126: min presses = 236
# Line 127: min presses = 165
# Line 128: min presses = 56
# Line 129: min presses = 147
# Line 130: min presses = 262
# Line 131: min presses = 56
# Line 132: min presses = 232
# Line 133: min presses = 90
# Line 134: min presses = 136
# Line 135: min presses = 100
# Line 136: min presses = 118
# Line 137: min presses = 110
# Line 138: min presses = 201
# Line 139: min presses = 80
# Line 140: min presses = 110
# Line 141: min presses = 195
# Line 142: min presses = 161
# Line 143: min presses = 73
# Line 144: min presses = 126
# Line 145: min presses = 57
# Line 146: min presses = 51
# Line 147: min presses = 109
# Line 148: min presses = 70
# Line 149: min presses = 237
# Line 150: min presses = 229
# Line 151: min presses = 22
# Line 152: min presses = 76
# Line 153: min presses = 125
# Line 154: min presses = 123
# Line 155: min presses = 92
# Line 156: min presses = 212
# Line 157: min presses = 34
# Line 158: min presses = 55
# Line 159: min presses = 100
# Line 160: min presses = 11
# Line 161: min presses = 87
# Line 162: min presses = 56
# Line 163: min presses = 194
# Line 164: min presses = 63
# Line 165: min presses = 216
# Line 166: min presses = 28
# Line 167: min presses = 76
# Line 168: min presses = 59
# Line 169: min presses = 233
# Line 170: min presses = 138
# Line 171: min presses = 227
# Line 172: min presses = 43
# Line 173: min presses = 56
# Line 174: min presses = 21
# Line 175: min presses = 52
# Line 176: min presses = 77
# Line 177: min presses = 68
# Line 178: min presses = 199
# Line 179: min presses = 99
# Line 180: min presses = 22
# Line 181: min presses = 115
# Line 182: min presses = 55
# Line 183: min presses = 103
# Line 184: min presses = 222
# Line 185: min presses = 93
# Line 186: min presses = 94
# Line 187: min presses = 72
# Total min presses (Part Two) = 20617
